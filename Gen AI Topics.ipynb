# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya-vijapurapu/Aditya-vijapurapu-NLP-web-scrapping-project/blob/main/Gen%20AI%20Topics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Term Frequency - Inverse Document Frequency

from sklearn.feature_extraction.text import TfidfVectorizer
# create a dummy dataset
corpus=[
    "I love machine learning",
    "Machine Learning is fun",
    "I enjoy learning new things",
    "Natural language processing is a part of machine learning"
]
# Assign tfidf to v
v = TfidfVectorizer()
result = v.fit_transform(corpus)
print(v.vocabulary_)
# Out:
# {'love': 5, 'machine': 6, 'learning': 4, 'is': 2, 'fun': 1, 'enjoy': 0, 'new': 8, 'things': 12, 'natural': 7, 'language': 3, 'processing': 11, 'part': 10, 'of': 9}

# %%
print(result)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 19 stored elements and shape (4, 13)>
#   Coords	Values
#   (0, 5)	0.7715790094657221
#   (0, 6)	0.4924888870251974
#   (0, 4)	0.40264193560603856
#   (1, 6)	0.42075315164463567
#   (1, 4)	0.3439932714296342
#   (1, 2)	0.5197138488789809
#   (1, 1)	0.6591911178676787
#   (2, 4)	0.2884767487500274
#   (2, 0)	0.5528053199908667
#   (2, 8)	0.5528053199908667
#   (2, 12)	0.5528053199908667
#   (3, 6)	0.2542729780776389
#   (3, 4)	0.20788482088176372
#   (3, 2)	0.31407771418017194
#   (3, 7)	0.39836775555304266
#   (3, 3)	0.39836775555304266
#   (3, 11)	0.39836775555304266
#   (3, 10)	0.39836775555304266
#   (3, 9)	0.39836775555304266

# %%
all_feature_names = v.get_feature_names_out()
for word in all_feature_names:
    indx = v.vocabulary_.get(word)
    idf_score=v.idf_[indx]
    print(f"{word} : {idf_score}")
# Out:
# enjoy : 1.916290731874155
# fun : 1.916290731874155
# is : 1.5108256237659907
# language : 1.916290731874155
# learning : 1.0
# love : 1.916290731874155
# machine : 1.2231435513142097
# natural : 1.916290731874155
# new : 1.916290731874155
# of : 1.916290731874155
# part : 1.916290731874155
# processing : 1.916290731874155
# things : 1.916290731874155

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = [
    "If you feel comfortable",
    "I would be immensely grateful for your referral",
    "I understand the importance of a recommendation"
]
v = TfidfVectorizer()
result = v.fit_transform(corpus)
print(v.vocabulary_)
# Out:
# {'if': 5, 'you': 14, 'feel': 2, 'comfortable': 1, 'would': 13, 'be': 0, 'immensely': 6, 'grateful': 4, 'for': 3, 'your': 15, 'referral': 10, 'understand': 12, 'the': 11, 'importance': 7, 'of': 8, 'recommendation': 9}

# %%
print(result)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 16 stored elements and shape (3, 16)>
#   Coords	Values
#   (0, 5)	0.5
#   (0, 14)	0.5
#   (0, 2)	0.5
#   (0, 1)	0.5
#   (1, 13)	0.37796447300922725
#   (1, 0)	0.37796447300922725
#   (1, 6)	0.37796447300922725
#   (1, 4)	0.37796447300922725
#   (1, 3)	0.37796447300922725
#   (1, 15)	0.37796447300922725
#   (1, 10)	0.37796447300922725
#   (2, 12)	0.4472135954999579
#   (2, 11)	0.4472135954999579
#   (2, 7)	0.4472135954999579
#   (2, 8)	0.4472135954999579
#   (2, 9)	0.4472135954999579

# %%
import pandas as pd
df = pd.DataFrame(result.toarray(),columns=v.get_feature_names_out())
df
# Out:
#          be  comfortable  feel       for  grateful   if  immensely  \
# 0  0.000000          0.5   0.5  0.000000  0.000000  0.5   0.000000
# 1  0.377964          0.0   0.0  0.377964  0.377964  0.0   0.377964
# 2  0.000000          0.0   0.0  0.000000  0.000000  0.0   0.000000
#
#    importance        of  recommendation  referral       the  understand  \
# 0    0.000000  0.000000        0.000000  0.000000  0.000000    0.000000
# 1    0.000000  0.000000        0.000000  0.377964  0.000000    0.000000
# 2    0.447214  0.447214        0.447214  0.000000  0.447214    0.447214
#
#       would  you      your
# 0  0.000000  0.5  0.000000
# 1  0.377964  0.0  0.377964
# 2  0.000000  0.0  0.000000
